# %% [markdown]
# # 1. Sin ve Cos çizimi

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
plt.figure(figsize=(12,6))


t = np.arange(0.0, 2.0, 0.00001)
c = np.cos(-3.14 * np.pi * t)
plt.plot(t,c, linestyle = 'dashed')

t = np.arange(0.0, 2.0, 0.00001)
s = np.sin(1.62 * np.pi * t)
plt.plot(t,-s, linestyle = 'dashed')

plt.xlabel('Zaman (s)')
plt.ylabel('asin+bcos')
plt.title('asin+bcos - Zaman Grafiği')

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.savefig('grafik.png')
plt.show()

# %% [markdown]
# # 2. DATAFRAME OLUŞTURMA VE OKUMA

# %%
data = {
    'ogrenciler': ["Zehra","Baran","Deniz","Yasmina","Meltem","Ceren","Eslem", "Onur", "Hasan", "Sena","Ömer", "Ömer Şahin"],
    'bolum': ["Fizik","Metalurji ve Malzeme Mühendisliği","Fizik","Fizik","Fizik","Fizik","Fizik", "Kimya", "Biyoloji", "Bilgisayar Mühendisliği","Fizik","Fizik"],
    'iyonosfer tarihi vize sonucları': [100,87,78,70,75,81,79,28,85,80,57,83],
    'iyonosfer tarihi 2. vize sonucları':[98,90,65,83,76,85,81,71,90,87,79,89],
    'iyonosfer tarihi final sonucları': [100,100,89,90,80,92,91,40,100,98,60,98]
}

df = pd.DataFrame(data,
                  columns =['ogrenciler','bolum','iyonosfer tarihi vize sonucları','iyonosfer tarihi 2. vize sonucları','iyonosfer tarihi final sonucları'])


df.to_excel('grades.xlsx')


print(df)
# Out:
#     ogrenciler                              bolum  \
# 0        Zehra                              Fizik
# 1        Baran  Metalurji ve Malzeme Mühendisliği
# 2        Deniz                              Fizik
# 3      Yasmina                              Fizik
# 4       Meltem                              Fizik
# 5        Ceren                              Fizik
# 6        Eslem                              Fizik
# 7         Onur                              Kimya
# 8        Hasan                           Biyoloji
# 9         Sena            Bilgisayar Mühendisliği
# 10        Ömer                              Fizik
# 11  Ömer Şahin                              Fizik
#
#     iyonosfer tarihi vize sonucları  iyonosfer tarihi 2. vize sonucları  \
# 0                               100                                  98
# 1                                87                                  90
# 2                                78                                  65
# ...

# %%
pd.read_excel("grades.xlsx")
# Out:
#     Unnamed: 0  ogrenciler                              bolum  \
# 0            0       Zehra                              Fizik
# 1            1       Baran  Metalurji ve Malzeme Mühendisliği
# 2            2       Deniz                              Fizik
# 3            3     Yasmina                              Fizik
# 4            4      Meltem                              Fizik
# 5            5       Ceren                              Fizik
# 6            6       Eslem                              Fizik
# 7            7        Onur                              Kimya
# 8            8       Hasan                           Biyoloji
# 9            9        Sena            Bilgisayar Mühendisliği
# 10          10        Ömer                              Fizik
# 11          11  Ömer Şahin                              Fizik
#
#     iyonosfer tarihi vize sonucları  iyonosfer tarihi 2. vize sonucları  \
# 0                               100                                  98
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ogrenciler                          12 non-null     object
#  1   bolum                               12 non-null     object
#  2   iyonosfer tarihi vize sonucları     12 non-null     int64
#  3   iyonosfer tarihi 2. vize sonucları  12 non-null     int64
#  4   iyonosfer tarihi final sonucları    12 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 612.0+ bytes
# None

# %% [markdown]
# # 3. Notların CSV formatına getirilmesi ve ilgili grafikler

# %%
pd.read_excel("grades.xlsx")
# Out:
#     Unnamed: 0  ogrenciler                              bolum  \
# 0            0       Zehra                              Fizik
# 1            1       Baran  Metalurji ve Malzeme Mühendisliği
# 2            2       Deniz                              Fizik
# 3            3     Yasmina                              Fizik
# 4            4      Meltem                              Fizik
# 5            5       Ceren                              Fizik
# 6            6       Eslem                              Fizik
# 7            7        Onur                              Kimya
# 8            8       Hasan                           Biyoloji
# 9            9        Sena            Bilgisayar Mühendisliği
# 10          10        Ömer                              Fizik
# 11          11  Ömer Şahin                              Fizik
#
#     iyonosfer tarihi vize sonucları  iyonosfer tarihi 2. vize sonucları  \
# 0                               100                                  98
# ...

# %%
finalgrades=[]
for x in range(0,12):
    i = (3*df.iloc[x,2]+3*df.iloc[x,3]+4*df.iloc[x,4])/10
    finalgrades.append(i)
print(finalgrades)
# Out:
# [99.4, 93.1, 78.5, 81.9, 77.3, 86.6, 84.4, 45.7, 92.5, 89.3, 64.8, 90.8]

# %%
df['Ağırlıklı Dönem Sonu Notları'] = finalgrades
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ogrenciler                          12 non-null     object
#  1   bolum                               12 non-null     object
#  2   iyonosfer tarihi vize sonucları     12 non-null     int64
#  3   iyonosfer tarihi 2. vize sonucları  12 non-null     int64
#  4   iyonosfer tarihi final sonucları    12 non-null     int64
#  5   Ağırlıklı Dönem Sonu Notları        12 non-null     float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 708.0+ bytes
# None

# %%
df
# Out:
#     ogrenciler                              bolum  \
# 0        Zehra                              Fizik
# 1        Baran  Metalurji ve Malzeme Mühendisliği
# 2        Deniz                              Fizik
# 3      Yasmina                              Fizik
# 4       Meltem                              Fizik
# 5        Ceren                              Fizik
# 6        Eslem                              Fizik
# 7         Onur                              Kimya
# 8        Hasan                           Biyoloji
# 9         Sena            Bilgisayar Mühendisliği
# 10        Ömer                              Fizik
# 11  Ömer Şahin                              Fizik
#
#     iyonosfer tarihi vize sonucları  iyonosfer tarihi 2. vize sonucları  \
# 0                               100                                  98
# 1                                87                                  90
# 2                                78                                  65
# ...

# %%
#u, ortalama değeri
u=df['Ağırlıklı Dönem Sonu Notları'].mean()
print(u)
#s, standart sapma
s=np.std(df['Ağırlıklı Dönem Sonu Notları'])
print(s)
# Out:
# 82.02499999999999
# 13.969438368572064

# %%
## Verilerimizin normal dağıldığını ve güvenilirliğinin %95 olduğunu düşünelim. Veri sayımız 20'den az olduğu için t testi yapalım.
## t testimizin formülü şu şekildedir: u+- t.s/n**1/2
## t değeri %95 güvenilirlik değerinde ve 12 verimiz olduğu için 11 (12-1) serbestik derecesine sahipken 1.796 değeri alıyor.
upperlimit= u + 1.796*s/12**1/2
lowerlimit= u - 1.796*s/12**1/2
print("Notların alt limiti: {}".format(lowerlimit))
# Out:
# Notların alt limiti: 80.97962036208519

# %%
result=list
df["Passed/You shalll not PASS!"] = result

for x in df.index:
  if df.loc[x, 'Ağırlıklı Dönem Sonu Notları'] < lowerlimit:
    df.loc[x, "Passed/You shalll not PASS!"] = "You shalll not PASS!"
  else:
    df.loc[x, "Passed/You shalll not PASS!"] = "Passed"

# %%
df
# Out:
#     ogrenciler                              bolum  \
# 0        Zehra                              Fizik
# 1        Baran  Metalurji ve Malzeme Mühendisliği
# 2        Deniz                              Fizik
# 3      Yasmina                              Fizik
# 4       Meltem                              Fizik
# 5        Ceren                              Fizik
# 6        Eslem                              Fizik
# 7         Onur                              Kimya
# 8        Hasan                           Biyoloji
# 9         Sena            Bilgisayar Mühendisliği
# 10        Ömer                              Fizik
# 11  Ömer Şahin                              Fizik
#
#     iyonosfer tarihi vize sonucları  iyonosfer tarihi 2. vize sonucları  \
# 0                               100                                  98
# 1                                87                                  90
# 2                                78                                  65
# ...

# %%
df.to_csv("grades.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ogrenciler                          12 non-null     object
#  1   bolum                               12 non-null     object
#  2   iyonosfer tarihi vize sonucları     12 non-null     int64
#  3   iyonosfer tarihi 2. vize sonucları  12 non-null     int64
#  4   iyonosfer tarihi final sonucları    12 non-null     int64
#  5   Ağırlıklı Dönem Sonu Notları        12 non-null     float64
#  6   Passed/You shalll not PASS!         12 non-null     object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 804.0+ bytes
# None

# %%
#df['Passed/You shalll not PASS!'] = pd.to_str(df['Passed/You shalll not PASS!'])

# %%
dg=pd.read_csv("grades.csv")

# %%
dg["Ağırlıklı Dönem Sonu Notları"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#dg.loc[0][1]
